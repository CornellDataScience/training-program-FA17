# %% [markdown]
# <p style="font-family: Arial; font-size:3.25em;color:navy; font-style:bold"><br>
# Lecture 0: Introduction to the Course Logistics
# </p><br>
#
# <p style="font-family: Arial; font-size:1.35em;color:#2462C0; font-style:bold"><br>
# Welcome to the Cornell Data Science Training program!
# </p>
#
# Through these lectures and exercises, we aim to teach you basic data science concepts and how to apply them using a data science language. The topics that we will cover will include, but will not be limited to:
#
# * Tools for Data Science
# * Data Cleaning and Manipulation
# * Data visualization
# * Supervised Learning Algorithms
# * Unsupervised Learning
# * Meta-Learning
#
# We'll start with the basics of the language, to advanced applications in more advanced concepts. By the end of the course, you will have the foundation and basic skills to contribute to any subteam on Cornell Data Science, and to your career in this explosive field.
# <p style="font-family: Arial; font-size:1.35em;color:#2462C0; font-style:bold"><br>
# Recap: Why Data Science? And why Python?
# </p>
#
# Before we begin to explore Numpy and all of its applications, we need to remember why data science is so important today and why data scientists choose Python. Data science can be thought of as the basis for **empirical research**, since data is used to inform our **hypotheses** and provide **observations**. In many cases, this data is used either by businesses or by scientists to inform their understanding of a phenomenon. We use a combination of exploratory data analysis and modeling to draw conclusions from larges troves of data. Data science allows us to:
#
# * **analyze the past**, and
# * **predict the future** through large scale data processing.
#
# Our more recent ability to collect data in real time from many places in cluding websites, smart phones, and environmental sensors makes data science indredibly relevent in almost every industry, scientific discipline, or engineering endeavor today.
#
# So why is Python a good programming language for data science? Well, it is:
#
# * an easy-to-learn and readable language
# * an open language with a vibrant community
#
# Thanks to the efforts of this community, it offers an ever-growing set of data management, analytical processing, and visualization libraries, like Numpy, Pandas, and Sci-Kit Learn! Such libraries make Python applicable to every aspect of data science.
# Lastly, but very importantly, **Jupyter Notebooks** make Python-based analysis more producible and repeatable. They also provide built-in training and communication support to help with team collaboration.
#
# Now that we know why data science is so important and why we use Python, let's start to learn about Jupyter IPython Notebooks!

# %% [markdown]
# <p style="font-family: Arial; font-size:1.35em;color:#2462C0; font-style:bold"><br>
# Getting Started with Jupyter Notebooks
# </p>
#
# Jupyter Notebooks have led to it rapidly gaining broad acceptance within the data science community. Let's start with the key features of Jupyter Notebooks:
#
# * Documented Data Science
#     * Allows us to document data science process by combining notes, code, and graphics
#     * Allows others to read the notebooks and understand the motives behind each step and why decisions were made (good collaboration)
# * Reproducible science
#     * Allows you to show others exactly how you conducted the research
#     * Allows for replication and inspection of other’s methods
# * Presentation of Results
#     * Can easily share notebooks with colleagues and present results as well
# * Support for Julia, Python, and R
#     * 3 of most popular programming languages for conducting data science
#
# Now that we know the key features of Jupyter Notebook, let's download and install it on our computer.
# <br>
# If you are an experienced Python user, you can simply go to the Command Prompt (Windows) or Terminal (Mac) and use:
#
#     pip3 install jupyter
#
# where `pip3` is a Python Package Manager for version 3.
#
# However, if you are new to Python, we **highly recommend** downloading Anaconda.
#
#
#
#
#
#
# Now, let's create a Jupyter Notebook and run Python code in the notebook!
#
#
#
# Dashboard = first page of Jupyter Notebook
# Lists the contents of the folder you launched Jupyter Notebook from
# Can navigate around your file system through this dashboard
# This file system is where the Jupyter Notebook server is running
# Create a new notebook with the “New” button on the upper right corner
# Select Python 3
# Rename by clicking “Untitled” at top of notebook and typing in your new name
# Notebook application vs. notebook
# Notebook application = a web application that creates the interface in the browser and executed Python and other language’s code
# Notebook = file format with ipynb extension that saves code, images, and text in a single document easy enough to be shared
# Run code in a cell by either clicking the play button in toolbar (next to stop button) or clicking the cell and hitting Enter and Shift simultaneously
# Running the code in a cell creates a new cell right below it
# Code is executed in a Python process called the kernel
# There’s a kernel running in the background for each open notebook or browser tab
# Jupyter notebook application talks to the kernel to have it load the data and execute code
# Jupyter notebook = a collection of cells, some including code
# Printing something = shows up as text right under code cell
# Running a calculation without an assignment or print statement = comes up as an output line under code line
# _ (underscore) = refers to the output of the last cell executed
# Can go back to a cell, update it, and run it again
# Number in brackets next to “In” = shows the order of execution
# If you update a cell and run it again, that number will change
# If you want to keep both sets of code (the original and the update), just copy and paste the code from the original into a new cell and update it in the new cell
# Copy and paste buttons in the toolbar
# Code doesn’t have to be one line – can do any type of Python code in the notebook
# Ex. Importing a module, printing a variable, creating sophisticated analysis or graphs
# Moving around among cells
# Up and down arrows = move between lines of cells and then cells
# Cell highlighted green
# Escape  up and down arrows = move between cells quickly (modal)
# Cell highlighted blue
# Cut cells to delete them (cut in the toolbar)
# Documenting Analysis with Markdown Text
# Goal = add and format text in Jupyter notebooks
# Use plus button in toolbar to add a new cell
# Change the purpose of the cell from cell to a markdown by choosing markdown from the dropdown menu in the toolbar
# Instead of “Code,” pick “Markdown”
# Can write text in markdown cells instead of code
# Good for documenting data analysis pipeline
# Run cell to change into simple text in notebook
# Markdown cell is a simple text markup, but can format and beautify to make text look nicer
# Use * followed by a space and then text to create a bulleted list
# Use # followed by a space and then text to create a title/heading
# Can make up to 5 levels of headings
# Use ** to create bold text (no space between ** and text), ** at end too
# Use * to create italicized text (no space between * and text), * at end too
# Use http:// or copy paste a link to create a link to a webpage
# Use $ to create a LaTeX equation, $ at end too
# Markdowns = code commenting, documenting code, writing a scientific paper
# Additional Tips
# Goal = manage your Jupyter notebook files and share notebooks with your team
# After generating an image or a graph (using matplotlib etc. – will learn later), can use markdowns around it to explain that cell
# Convert cell below graph to a markdown, explain graph
# When done with notebook, we need to save it
# Notebook application saves in checkpoints as you’re typing, but can also use the File  Save and Checkpoint button to save
# Even after closing a notebook, kernel remains running
# To stop a notebook from running, click File  Close and Halt
# To run again, just click on notebook and it will begin running again
# To save a non-executable version of the notebook and keep it in your archives, click File  Download as  HTML
# Saves a version of the Notebook that cannot be edited – like a record/archive
# Using UNIX in Jupyter
# Jupyter Notebooks provide an easier and more interactive way to use UNIX commands
# Use an exclamation point before commands to execute them like we execute them on a UNIX shell
